# %%
pip install ipywidgets
# Out:
# ...
#      -------------------------------------- 123.4/123.4 KB 7.1 MB/s eta 0:00:00
# ...
#      ------------------------------------- 245.1/245.1 KB 14.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.6/1.6 MB 25.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
